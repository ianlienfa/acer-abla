# %%
filename="test"

# %%
# !python3 main.py -f "$filename"
# Out:
# Writing log into: test
# Episode #0, episode rewards 17.0
# Episode #1, episode rewards 13.0
# Episode #2, episode rewards 16.0
# Episode #3, episode rewards 27.0
# Episode #4, episode rewards 65.0
# Episode #5, episode rewards 15.0
# Episode #6, episode rewards 48.0
# Episode #7, episode rewards 13.0
# Episode #8, episode rewards 22.0
# Episode #9, episode rewards 25.0
# Episode #10, episode rewards 15.0
# Episode #11, episode rewards 34.0
# Episode #12, episode rewards 25.0
# Episode #13, episode rewards 12.0
# Episode #14, episode rewards 48.0
# Episode #15, episode rewards 11.0
# Episode #16, episode rewards 40.0
# Episode #17, episode rewards 27.0
# Episode #18, episode rewards 14.0
# Episode #19, episode rewards 12.0
# Episode #20, episode rewards 11.0
# Episode #21, episode rewards 23.0
# Episode #22, episode rewards 13.0
# Episode #23, episode rewards 35.0
# Episode #24, episode rewards 20.0
# Episode #25, episode rewards 10.0
# Episode #26, episode rewards 14.0
# ...

# %%
import matplotlib.pyplot as plt

f = open(filename, "r")
rewards = list(f.read().split(" "))
plt.plot(rewards)
plt.show()
