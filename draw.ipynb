# %%
dirname="reward"

# %%
# !python3 main.py -f "$dirname"
# Out:
# Writing log into: reward_2004/
# Episode #0, noise ratio 1.00Episode #0, noise ratio 1.00Episode #0, noise ratio 1.00Episode #0, noise ratio 1.00Traceback (most recent call last):
#   File "main.py", line 63, in <module>
#     process.join()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 140, in join
#     res = self._popen.wait(timeout)
#   File "/usr/lib/python3.7/multiprocessing/popen_fork.py", line 48, in wait
#     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#   File "/usr/lib/python3.7/multiprocessing/popen_fork.py", line 28, in poll
#     pid, sts = os.waitpid(self.pid, flag)
# KeyboardInterrupt
# , episode rewards -12.517922401428223
# filename:  reward_2004/reward_2004_13895.txt
# Episode #1, noise ratio 0.98, episode rewards -12.517922401428223
# filename:  reward_2004/reward_2004_13893.txt
# Episode #1, noise ratio 0.98, episode rewards -12.517922401428223
# filename:  reward_2004/reward_2004_13896.txt

# %%
"""
Change the file name here!
"""
filename="reward_2004"

# %%
path = dirname + "/" + filename + ".txt"

# %%
import matplotlib.pyplot as plt

f = open(path, "r")
rewards = list((f.read().split(" ")))
rewards = rewards[:-1]
rewards = [float(i) for i in rewards]
plt.plot(rewards)
plt.show()
